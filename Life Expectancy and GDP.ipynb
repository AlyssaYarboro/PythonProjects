# %% [markdown]
# ## Life Expectancy and GDP in Different Countries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.read_csv(r"C:\Users\amyar\Downloads\Life-Expectancy-and-GDP-Starter (1)\Life-Expectancy-and-GDP-Starter\all_data.csv")

# %%
df
# Out:
#      Country  Year  Life expectancy at birth (years)           GDP
# 0      Chile  2000                              77.3  7.786093e+10
# 1      Chile  2001                              77.3  7.097992e+10
# 2      Chile  2002                              77.8  6.973681e+10
# 3      Chile  2003                              77.9  7.564346e+10
# 4      Chile  2004                              78.0  9.921039e+10
# ..       ...   ...                               ...           ...
# 91  Zimbabwe  2011                              54.9  1.209845e+10
# 92  Zimbabwe  2012                              56.6  1.424249e+10
# 93  Zimbabwe  2013                              58.0  1.545177e+10
# 94  Zimbabwe  2014                              59.2  1.589105e+10
# 95  Zimbabwe  2015                              60.7  1.630467e+10
#
# [96 rows x 4 columns]

# %% [markdown]
# ## Modifying the Data Frame

# %% [markdown]
# ##### Let's modify the DataFrame columns so they are a little easier to work with. All the columns are either one word or an abbreviated. Let's change the column 'Life expectancy at birth (years)' to a shorthand so it's easier to work with in the next steps.

# %%
df.rename(columns = {"Life expectancy at birth (years)": "LEABY"}, inplace = True)

# %%
print(df.head())
# Out:
#   Country  Year  LEABY           GDP
# 0   Chile  2000   77.3  7.786093e+10
# 1   Chile  2001   77.3  7.097992e+10
# 2   Chile  2002   77.8  6.973681e+10
# 3   Chile  2003   77.9  7.564346e+10
# 4   Chile  2004   78.0  9.921039e+10

# %% [markdown]
# ## Creating A Violin Plot

# %%
fig = plt.subplots(figsize=(15, 20))
sns.violinplot(x = 'Country', y = 'LEABY', data = df)
plt.show()

# %% [markdown]
# ## Creating Bar Plots

# %%
ax = sns.barplot(x = 'Country', y = 'LEABY', data = df)
plt.xticks(rotation=90)
plt.show()

# %%
ax = sns.barplot(x = 'Country', y = 'GDP', data = df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Bar Plots of GDP and Life Expectancy over Years

# %%
ax = plt.subplots(figsize = (15, 20))
ax = sns.barplot(x = 'Country', y = 'LEABY', data = df, hue = 'Year', palette = 'rainbow')
plt.xticks(rotation = 90)
plt.ylabel(ylabel)
ax.set(ylabel = 'Life expectancy at birth in years')
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 20))
ax = sns.barplot(x = 'Country', y = 'GDP', data = df, hue = 'Year', palette = 'rainbow')
plt.xticks(rotation = 90)
ylabel = 'GDP in Trillions (USD)'
plt.ylabel(ylabel)
plt.show()

# %% [markdown]
# ## Scatter Plots of Life Expectancy and GDP

# %%
g = sns.FacetGrid(df, col='Year', hue='Country', col_wrap=4, height=2)
g = (g.map(plt.scatter, 'GDP', 'LEABY', edgecolor='w').add_legend())
plt.show()

# %% [markdown]
# ## Line Plots of Life Expectancy

# %%
g2 = sns.FacetGrid(df, col='Country', col_wrap=3, height=4)
g2 = (g2.map(plt.plot, 'Year', 'LEABY', color='green').add_legend())

# %% [markdown]
# ## Line Plots of GDP

# %%
g3 = sns.FacetGrid(df, col='Country', col_wrap=3, height=4)
g3 = (g3.map(plt.plot, 'Year', 'GDP').add_legend())
plt.show()
